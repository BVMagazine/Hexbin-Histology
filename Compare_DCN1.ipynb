# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd


# Step 1: Load the black and white images
# ~Change Me~
image1 = Image.open("C:/Users/silvermanq/Desktop/128-1.jpg")
#image2 = Image.open("C:/Users/silvermanq/Desktop/113DCN_Vglut2_1ai.jpg")

# Step 2: Convert the images to grayscale (if not already in grayscale)
gray_image1 = image1.convert('L')
#gray_image2 = image2.convert('L')

# Step 3: Extract pixel data
# Convert the grayscale images into numpy arrays
image_data1 = np.array(gray_image1)
#image_data2 = np.array(gray_image2)

# Step 4: Average the pixel intensities
average_image_data = (image_data1) / 1

# Step 5: Create the hexbin plot
# Use numpy to get the x and y positions of each pixel
x, y = np.meshgrid(np.arange(average_image_data.shape[1]), np.arange(average_image_data.shape[0]))

# Flatten the arrays to 1D for hexbin plotting
x = x.flatten()
y = y.flatten()
z = average_image_data.flatten()  # Averaged grayscale intensity values

# Create figure with custom layout
# figsize scale to match original images (you'll just have to adjust this)
# ~Change Me~
fig = plt.figure(figsize=(14, 10))
gs = plt.GridSpec(2, 3, height_ratios=[1, 4], width_ratios=[0.25, 4, 1])

# Define your desired maximum intensity value
# ~Change Me~
max_intensity = 100  # or any value you want

# Create main axes and marginal axes
ax_main = fig.add_subplot(gs[1, 1])
ax_marg_x = fig.add_subplot(gs[0, 1], sharex=ax_main)
ax_marg_y = fig.add_subplot(gs[1, 2], sharey=ax_main)
ax_colorbar = fig.add_subplot(gs[1, 0])

# Create hexbin plot with vmax
# Make sure to set the grid size match the ratio of the original images and weird math because of hexagons
# [grid_y=(desired bins)] [grid_x=(desired bins * 1.73)*(x/y pixel ratio)]
# ~Change Me~
grid_x= 60  # Number of bins in x direction
grid_y = 30  # Number of bins in y direction
hb = ax_main.hexbin(x, y, C=z, gridsize=(grid_x, grid_y), cmap='gnuplot', linewidths=0.5, edgecolors='face', vmax=max_intensity / 2)
plt.colorbar(hb, cax=ax_colorbar, label='Intensity')

# Step 6: Create marginal distributions
# Calculate peak values and create bins
z_reshape = z.reshape(average_image_data.shape)
x_peaks = np.mean(z_reshape, axis=0)
y_peaks = np.mean(z_reshape, axis=1)

# Create evenly spaced points for x and y axes
x_points = np.linspace(0, max(x), grid_x)
y_points = np.linspace(0, max(y), grid_y)

# Calculate binned values
x_bins = np.linspace(0, len(x_peaks), (grid_x + 1))
y_bins = np.linspace(0, len(y_peaks), (grid_y + 1))
x_digitized = np.digitize(np.arange(len(x_peaks)), x_bins)
y_digitized = np.digitize(np.arange(len(y_peaks)), y_bins)

x_binned = [np.mean(x_peaks[x_digitized == i]) for i in range(1, len(x_bins))]
y_binned = [np.mean(y_peaks[y_digitized == i]) for i in range(1, len(y_bins))]

# Plot data
sns.lineplot(x=x_points, y=x_binned, ax=ax_marg_x, color='blue')
sns.lineplot(x=y_binned, y=y_points, ax=ax_marg_y, color='red', orient='y')

# Set y-axis limit for marginal x plot (intensity)
ax_marg_x.set_yscale('log')
ax_marg_x.set_ylim(1, max_intensity)
# Set x-axis limit for marginal y plot (intensity)
ax_marg_y.set_xscale('log')
ax_marg_y.set_xlim(1, max_intensity)

# Save marginal distributions as CSV
# ~Change Me~
dfx = pd.DataFrame({
    'x_points': x_points,
    'x_binned': x_binned,
})
dfx.to_csv("C:/Users/silvermanq/Desktop/Figures/marginal_distributions_CBDCN1_X.csv", index=False)
dfy = pd.DataFrame({
    'y_points': y_points,
    'y_binned': y_binned
})
dfy.to_csv("C:/Users/silvermanq/Desktop/Figures/marginal_distributions_CBDCN1_Y.csv", index=False)

# Adjust appearance
# ~Change Me~
ax_marg_x.axis('on')
ax_marg_y.axis('on')
ax_main.invert_yaxis()
ax_main.set_xlabel('micrometers')
ax_main.set_ylabel('micrometers')
ax_main.set_title('CB DCN 1')

plt.tight_layout()

# Save plot as SVG
# ~Change Me~
plt.savefig("C:/Users/silvermanq/Desktop/Figures/CBDCN1_averaged_hexbin.svg", format='svg', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd


# Step 1: Load the black and white images
# ~Change Me~
image1 = Image.open("C:/Users/silvermanq/Desktop/140-1.jpg")
#image2 = Image.open("C:/Users/silvermanq/Desktop/113DCN_Vglut2_1ai.jpg")

# Step 2: Convert the images to grayscale (if not already in grayscale)
gray_image1 = image1.convert('L')
#gray_image2 = image2.convert('L')

# Step 3: Extract pixel data
# Convert the grayscale images into numpy arrays
image_data1 = np.array(gray_image1)
#image_data2 = np.array(gray_image2)

# Step 4: Average the pixel intensities
average_image_data = (image_data1) / 1

# Step 5: Create the hexbin plot
# Use numpy to get the x and y positions of each pixel
x, y = np.meshgrid(np.arange(average_image_data.shape[1]), np.arange(average_image_data.shape[0]))

# Flatten the arrays to 1D for hexbin plotting
x = x.flatten()
y = y.flatten()
z = average_image_data.flatten()  # Averaged grayscale intensity values

# Create figure with custom layout
# figsize scale to match original images (you'll just have to adjust this)
# ~Change Me~
fig = plt.figure(figsize=(14, 10))
gs = plt.GridSpec(2, 3, height_ratios=[1, 4], width_ratios=[0.25, 4, 1])

# Define your desired maximum intensity value
# ~Change Me~
max_intensity = 100  # or any value you want

# Create main axes and marginal axes
ax_main = fig.add_subplot(gs[1, 1])
ax_marg_x = fig.add_subplot(gs[0, 1], sharex=ax_main)
ax_marg_y = fig.add_subplot(gs[1, 2], sharey=ax_main)
ax_colorbar = fig.add_subplot(gs[1, 0])

# Create hexbin plot with vmax
# Make sure to set the grid size match the ratio of the original images and weird math because of hexagons
# [grid_y=(desired bins)] [grid_x=(desired bins * 1.73)*(x/y pixel ratio)]
# ~Change Me~
grid_x= 60  # Number of bins in x direction
grid_y = 30  # Number of bins in y direction
hb = ax_main.hexbin(x, y, C=z, gridsize=(grid_x, grid_y), cmap='gnuplot', linewidths=0.5, edgecolors='face', vmax=max_intensity / 2)
plt.colorbar(hb, cax=ax_colorbar, label='Intensity')

# Step 6: Create marginal distributions
# Calculate peak values and create bins
z_reshape = z.reshape(average_image_data.shape)
x_peaks = np.max(z_reshape, axis=0)
y_peaks = np.max(z_reshape, axis=1)

# Create evenly spaced points for x and y axes
x_points = np.linspace(0, max(x), grid_x)
y_points = np.linspace(0, max(y), grid_y)

# Calculate binned values
x_bins = np.linspace(0, len(x_peaks), (grid_x + 1))
y_bins = np.linspace(0, len(y_peaks), (grid_y + 1))
x_digitized = np.digitize(np.arange(len(x_peaks)), x_bins)
y_digitized = np.digitize(np.arange(len(y_peaks)), y_bins)

x_binned = [np.mean(x_peaks[x_digitized == i]) for i in range(1, len(x_bins))]
y_binned = [np.mean(y_peaks[y_digitized == i]) for i in range(1, len(y_bins))]

# Plot data
sns.lineplot(x=x_points, y=x_binned, ax=ax_marg_x, color='blue')
sns.lineplot(x=y_binned, y=y_points, ax=ax_marg_y, color='red', orient='y')

# Set y-axis limit for marginal x plot (intensity)
##ax_marg_x.set_yscale('log')
ax_marg_x.set_ylim(1, max_intensity)
# Set x-axis limit for marginal y plot (intensity)
##ax_marg_y.set_xscale('log')
ax_marg_y.set_xlim(1, max_intensity)

# Save marginal distributions as CSV
# ~Change Me~
dfx = pd.DataFrame({
    'x_points': x_points,
    'x_binned': x_binned,
})
dfx.to_csv("C:/Users/silvermanq/Desktop/Figures/marginal_distributions_CRDCN1_X.csv", index=False)
dfy = pd.DataFrame({
    'y_points': y_points,
    'y_binned': y_binned
})
dfy.to_csv("C:/Users/silvermanq/Desktop/Figures/marginal_distributions_CRDCN1_Y.csv", index=False)

# Adjust appearance
# ~Change Me~
ax_marg_x.axis('on')
ax_marg_y.axis('on')
ax_main.invert_yaxis()
ax_main.set_xlabel('micrometers')
ax_main.set_ylabel('micrometers')
ax_main.set_title('CR DCN 1')

plt.tight_layout()

# Save plot as SVG
# ~Change Me~
plt.savefig("C:/Users/silvermanq/Desktop/Figures/CRDCN1_averaged_hexbin.svg", format='svg', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd


# Step 1: Load the black and white images
# ~Change Me~
image1 = Image.open("C:/Users/silvermanq/Desktop/113-1.jpg")
image2 = Image.open("C:/Users/silvermanq/Desktop/125-1.jpg")
image3 = Image.open("C:/Users/silvermanq/Desktop/127-1.jpg")

# Step 2: Convert the images to grayscale (if not already in grayscale)
gray_image1 = image1.convert('L')
gray_image2 = image2.convert('L')
gray_image3 = image3.convert('L')

# Step 3: Extract pixel data
# Convert the grayscale images into numpy arrays
image_data1 = np.array(gray_image1)
image_data2 = np.array(gray_image2)
image_data3 = np.array(gray_image3)

# Step 4: Average the pixel intensities
average_image_data = (image_data1 + image_data2 + image_data3) / 3

# Step 5: Create the hexbin plot
# Use numpy to get the x and y positions of each pixel
x, y = np.meshgrid(np.arange(average_image_data.shape[1]), np.arange(average_image_data.shape[0]))

# Flatten the arrays to 1D for hexbin plotting
x = x.flatten()
y = y.flatten()
z = average_image_data.flatten()  # Averaged grayscale intensity values

# Create figure with custom layout
# figsize scale to match original images (you'll just have to adjust this)
# ~Change Me~
fig = plt.figure(figsize=(14, 10))
gs = plt.GridSpec(2, 3, height_ratios=[1, 4], width_ratios=[0.25, 4, 1])

# Define your desired maximum intensity value
# ~Change Me~
max_intensity = 100  # or any value you want

# Create main axes and marginal axes
ax_main = fig.add_subplot(gs[1, 1])
ax_marg_x = fig.add_subplot(gs[0, 1], sharex=ax_main)
ax_marg_y = fig.add_subplot(gs[1, 2], sharey=ax_main)
ax_colorbar = fig.add_subplot(gs[1, 0])

# Create hexbin plot with vmax
# Make sure to set the grid size match the ratio of the original images and weird math because of hexagons
# [grid_y=(desired bins)] [grid_x=(desired bins * 1.73)*(x/y pixel ratio)]
# ~Change Me~
grid_x= 60  # Number of bins in x direction
grid_y = 30  # Number of bins in y direction
hb = ax_main.hexbin(x, y, C=z, gridsize=(grid_x, grid_y), cmap='gnuplot', linewidths=0.5, edgecolors='face', vmax=max_intensity / 2)
plt.colorbar(hb, cax=ax_colorbar, label='Intensity')

# Step 6: Create marginal distributions
# Calculate peak values and create bins
z_reshape = z.reshape(average_image_data.shape)
x_peaks = np.max(z_reshape, axis=0)
y_peaks = np.max(z_reshape, axis=1)

# Create evenly spaced points for x and y axes
x_points = np.linspace(0, max(x), grid_x)
y_points = np.linspace(0, max(y), grid_y)

# Calculate binned values
x_bins = np.linspace(0, len(x_peaks), (grid_x + 1))
y_bins = np.linspace(0, len(y_peaks), (grid_y + 1))
x_digitized = np.digitize(np.arange(len(x_peaks)), x_bins)
y_digitized = np.digitize(np.arange(len(y_peaks)), y_bins)

x_binned = [np.mean(x_peaks[x_digitized == i]) for i in range(1, len(x_bins))]
y_binned = [np.mean(y_peaks[y_digitized == i]) for i in range(1, len(y_bins))]

# Plot data
sns.lineplot(x=x_points, y=x_binned, ax=ax_marg_x, color='blue')
sns.lineplot(x=y_binned, y=y_points, ax=ax_marg_y, color='red', orient='y')

# Set y-axis limit for marginal x plot (intensity)
ax_marg_x.set_yscale('log')
ax_marg_x.set_ylim(1, max_intensity)
# Set x-axis limit for marginal y plot (intensity)
ax_marg_y.set_xscale('log')
ax_marg_y.set_xlim(1, max_intensity)

# Save marginal distributions as CSV
# ~Change Me~
dfx = pd.DataFrame({
    'x_points': x_points,
    'x_binned': x_binned,
})
dfx.to_csv("C:/Users/silvermanq/Desktop/Figures/marginal_distributions_Runx3DCN1_X.csv", index=False)
dfy = pd.DataFrame({
    'y_points': y_points,
    'y_binned': y_binned
})
dfy.to_csv("C:/Users/silvermanq/Desktop/Figures/marginal_distributions_Runx3DCN1_Y.csv", index=False)

# Adjust appearance
# ~Change Me~
ax_marg_x.axis('on')
ax_marg_y.axis('on')
ax_main.invert_yaxis()
ax_main.set_xlabel('micrometers')
ax_main.set_ylabel('micrometers')
ax_main.set_title('Runx3 DCN 1')

plt.tight_layout()

# Save plot as SVG
# ~Change Me~
plt.savefig("C:/Users/silvermanq/Desktop/Figures/Runx3DCN1_averaged_hexbin.svg", format='svg', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd


# Step 1: Load the black and white images
# ~Change Me~
image1 = Image.open("C:/Users/silvermanq/Desktop/113-1.jpg")
image2 = Image.open("C:/Users/silvermanq/Desktop/125-1.jpg")
image3 = Image.open("C:/Users/silvermanq/Desktop/127-1.jpg")

# Step 2: Convert the images to grayscale (if not already in grayscale)
gray_image1 = image1.convert('L')
gray_image2 = image2.convert('L')
gray_image3 = image3.convert('L')

# Step 3: Extract pixel data
# Convert the grayscale images into numpy arrays
image_data1 = np.array(gray_image1)
image_data2 = np.array(gray_image2)
image_data3 = np.array(gray_image3)

# Step 4: Average the pixel intensities
average_image_data = (image_data1 + image_data2 + image_data3) / 3

# Step 5: Create the hexbin plot and figure set up
# Use numpy to get the x and y positions of each pixel
x, y = np.meshgrid(np.arange(average_image_data.shape[1]), np.arange(average_image_data.shape[0]))

# Flatten the arrays to 1D for hexbin plotting
x = x.flatten()
y = y.flatten()
z = average_image_data.flatten()  # Averaged grayscale intensity values

# Create figure with custom layout
# figsize scale to match original images (you'll just have to adjust this)
# ~Change Me~
fig = plt.figure(figsize=(14, 10))
gs = plt.GridSpec(2, 3, height_ratios=[1, 4], width_ratios=[0.25, 4, 1])

# Define your desired maximum intensity value
# ~Change Me~
max_intensity = 100  # or any value you want

# Create main axes, marginal axes, and colorbar
ax_main = fig.add_subplot(gs[1, 1])
ax_marg_x = fig.add_subplot(gs[0, 1], sharex=ax_main)
ax_marg_y = fig.add_subplot(gs[1, 2], sharey=ax_main)
ax_colorbar = fig.add_subplot(gs[1, 0])

# Create hexbin plot with vmax
# Make sure to set the grid size match the ratio of the original images and weird math because of hexagons
# [grid_y=(desired bins)] [grid_x=(desired bins * 1.73)*(x/y pixel ratio)]
# ~Change Me~
grid_x= 60  # Number of bins in x direction
grid_y = 30  # Number of bins in y direction
hb = ax_main.hexbin(x, y, C=z, gridsize=(grid_x, grid_y), cmap='gnuplot', linewidths=0.5, edgecolors='face', vmax=max_intensity / 2)
plt.colorbar(hb, cax=ax_colorbar, label='Intensity')

# Adjust appearance
# ~Change Me~
ax_marg_x.axis('on')
ax_marg_y.axis('on')
ax_main.invert_yaxis()
ax_main.set_xlabel('micrometers')
ax_main.set_ylabel('micrometers')
ax_main.set_title('Runx3 DCN 1')

# Step 6: Create marginal distributions
# Calculate peak values and create bins
z_reshape = z.reshape(average_image_data.shape)
x_peaks = np.max(z_reshape, axis=0)
y_peaks = np.max(z_reshape, axis=1)

# Create evenly spaced points for x and y axes
x_points = np.linspace(0, max(x), grid_x)
y_points = np.linspace(0, max(y), grid_y)

# Calculate binned values
x_bins = np.linspace(0, len(x_peaks), (grid_x + 1))
y_bins = np.linspace(0, len(y_peaks), (grid_y + 1))
x_digitized = np.digitize(np.arange(len(x_peaks)), x_bins)
y_digitized = np.digitize(np.arange(len(y_peaks)), y_bins)

x_binned = [np.mean(x_peaks[x_digitized == i]) for i in range(1, len(x_bins))]
y_binned = [np.mean(y_peaks[y_digitized == i]) for i in range(1, len(y_bins))]

# Plot data
sns.lineplot(x=x_points, y=x_binned, ax=ax_marg_x, color='blue')
sns.lineplot(x=y_binned, y=y_points, ax=ax_marg_y, color='red', orient='y')

# Set y-axis limit for marginal x plot (intensity)
ax_marg_x.set_yscale('log')
ax_marg_x.set_ylim(1, max_intensity)
# Set x-axis limit for marginal y plot (intensity)
ax_marg_y.set_xscale('log')
ax_marg_y.set_xlim(1, max_intensity)

# Save marginal distributions as CSV
# ~Change Me~
dfx = pd.DataFrame({
    'x_points': x_points,
    'x_binned': x_binned,
})
dfx.to_csv("C:/Users/silvermanq/Desktop/Figures/marginal_distributions_Runx3DCN1_X.csv", index=False)
dfy = pd.DataFrame({
    'y_points': y_points,
    'y_binned': y_binned
})
dfy.to_csv("C:/Users/silvermanq/Desktop/Figures/marginal_distributions_Runx3DCN1_Y.csv", index=False)


plt.tight_layout()

# Save plot as SVG
# ~Change Me~
plt.savefig("C:/Users/silvermanq/Desktop/Figures/Runx3DCN1_averaged_hexbin.svg", format='svg', dpi=300, bbox_inches='tight')
plt.show()
